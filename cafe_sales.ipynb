# %% [markdown]
# # Cafe Sale Analysis

# %% [markdown]
# #### Life cycle of Sales Dataset Project
#
# - Understanding the Problem Statement
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing
# - Model Training
# - Choose best model

# %% [markdown]
# ### Problem Statement
#
# -   The cafe sales dataset contains missing, erroneous, and unknown values across multiple columns, requiring comprehensive data cleaning to replace or remove inconsistent entries and ensure data integrity for accurate analysis.

# %% [markdown]
# ### Import Data and required packages

# %% [markdown]
# importing SQLconnector, Pandas, Numpy, Matplotlib and Warnings Liabrary

# %%
import mysql.connector 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Connect to the MySQL Database

# %%
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1406",
    database="cafe_sale"
)
cursor = connection.cursor()

# %% [markdown]
# Run the query

# %%
query = "select * from dirty_cafe_sales"

# %% [markdown]
# Connection close

# %%
dff = pd.read_sql(query,connection)
connection.close()

# %% [markdown]
# Copy the data set

# %%
df = dff.copy()

# %% [markdown]
# ## General Information of the dataset

# %% [markdown]
# Showing some top rows

# %%
df.head(10)
# Out:
#   Transaction ID      Item  Quantity  Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee         2             2.0         4.0
# 1    TXN_4977031      Cake         4             3.0        12.0
# 2    TXN_4271903    Cookie         4             1.0       ERROR
# 3    TXN_7034554     Salad         2             5.0        10.0
# 4    TXN_3160411    Coffee         2             2.0         4.0
# 5    TXN_2602893  Smoothie         5             4.0        20.0
# 6    TXN_4433211   UNKNOWN         3             3.0         9.0
# 7    TXN_6699534  Sandwich         4             4.0        16.0
# 8    TXN_4717867                   5             3.0        15.0
# 9    TXN_2064365  Sandwich         5             4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11
# 5     Credit Card                 2023-03-31
# 6           ERROR  Takeaway       2023-10-06
# 7            Cash   UNKNOWN       2023-10-28
# 8                  Takeaway       2023-07-28
# 9                  In-store       2023-12-31

# %% [markdown]
# info of nummerical columns

# %%
df.describe()
# Out:
#           Quantity  Price Per Unit
# count  9006.000000     9006.000000
# mean      3.023540        2.951865
# std       1.418644        1.277659
# min       1.000000        1.000000
# 25%       2.000000        2.000000
# 50%       3.000000        3.000000
# 75%       4.000000        4.000000
# max       5.000000        5.000000

# %% [markdown]
# Shape of the dataset

# %%
print(df.shape)
# Out:
# (9006, 8)

# %% [markdown]
# showing all columns of the dataset

# %%
for i in df.columns:
    print(i)
# Out:
# Transaction ID
# Item
# Quantity
# Price Per Unit
# Total Spent
# Payment Method
# Location
# Transaction Date

# %% [markdown]
# Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9006 entries, 0 to 9005
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    9006 non-null   object
#  1   Item              9006 non-null   object
#  2   Quantity          9006 non-null   int64
#  3   Price Per Unit    9006 non-null   float64
#  4   Total Spent       9006 non-null   object
#  5   Payment Method    9006 non-null   object
#  6   Location          9006 non-null   object
#  7   Transaction Date  9006 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 563.0+ KB

# %% [markdown]
# Showing Unique Values to each Columns

# %%
df.nunique()
# Out:
# Transaction ID      9006
# Item                  11
# Quantity               5
# Price Per Unit         6
# Total Spent           20
# Payment Method         6
# Location               5
# Transaction Date     368
# dtype: int64

# %% [markdown]
# Check the Missing Valueas

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %% [markdown]
# ### Data Pre-processing and Cleanning

# %%
df.replace("null", np.nan,regex=True, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df['Item'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df['Transaction ID'].unique())
print(df['Location'].unique())
print("categories in 'Item' variable:  ",end="")
print(df['Item'].unique())
# Out:
# ['TXN_1961373' 'TXN_4977031' 'TXN_4271903' ... 'TXN_7672686' 'TXN_5255387'
#  'TXN_6170729']
# ['Takeaway' 'In-store' 'UNKNOWN' '' 'ERROR']
# categories in 'Item' variable:  ['Coffee' 'Cake' 'Cookie' 'Salad' 'Smoothie' 'UNKNOWN' 'Sandwich' ''
#  'ERROR' 'Juice' 'Tea']

# %%
# print((df['Location']=="").sum())
# print((df['Location']=="ERROR").sum())
# print((df['Location']=="UNKNOWN").sum())
print((df['Location'].isin(['','ERROR','UNKNOWN']).sum()))
# Out:
# 3564

# %%
df['Location'].replace(["","ERROR","UNKNOWN"], "UNKNOWN", inplace=True)

# %%
df['Location'].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN'], dtype=object)

# %%
print((df['Item'].isin(['','ERROR','UNKNOWN']).sum()))
# Out:
# 859

# %%
df['Item'].replace(["", "ERROR", "UNKNOWN"],"Coffee", inplace=True)
print(df['Item'].unique())
# Out:
# ['Coffee' 'Cake' 'Cookie' 'Salad' 'Smoothie' 'Sandwich' 'Juice' 'Tea']

# %%
print(df['Quantity'].unique())
print(df['Price Per Unit'].unique())
print(df['Total Spent'].isin(["", "UNKNOWN","ERROR"]).sum())
# Out:
# [2 4 5 3 1]
# [2.  3.  1.  5.  4.  1.5]
# 462

# %% [markdown]
# - Replace these fake missing values with np.nan

# %%
df['Total Spent'] = df['Total Spent'].replace(["", "ERROR", "UNKNOWN"], np.nan)

# %%
mask_1 = df['Total Spent'].isnull() & df['Quantity'].notnull() & df['Price Per Unit'].notnull()
df.loc[mask_1, 'Total Spent'] = df.loc[mask_1, 'Quantity'] * df.loc[mask_1, 'Price Per Unit']

# %%
df['Quantity'] = df['Quantity'].replace(["", "ERROR", "UNKNOWN"],np.nan)

# %%
mask_2 = df['Quantity'].isnull() & df['Price Per Unit'].notnull() & df['Total Spent'].notnull()
df.loc[mask_2, 'Quantity'] = df.loc[mask_2, 'Total Spent'] / df.loc[mask_2, 'Price Per Unit']

# %%
df['Price Per Unit'] = df['Price Per Unit'].replace(["", "ERROR", "UNKNOWN"],np.nan)

# %%
mask_3 = df['Price Per Unit'].isnull() & df['Quantity'].notnull() & df['Total Spent'].notnull()
df.loc[mask_3, 'Price Per Unit'] = df.loc[mask_3, 'Total Spent'] / df.loc[mask_3, 'Quantity']

# %%
print(df['Quantity'].unique())
print(df['Price Per Unit'].unique())
print(df['Total Spent'].isin(["", "UNKNOWN","ERROR"]).sum())
# Out:
# [2 4 5 3 1]
# [2.0 3.0 1.0 5.0 4.0 1.5]
# 0

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df['Transaction Date'] = df['Transaction Date'].replace(["", "ERROR", "UNKNOWN"],np.nan)

# %% [markdown]
# - Only remove the null values

# %%
df = df.dropna(subset=['Transaction Date'])

# %%
df['Transaction Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# print(df['Transaction ID'].unique())
# print(df['Item'].unique())
# print(df['Quantity'].unique())
# print(df['Price Per Unit'].unique())
# print(df['Total Spent'].unique())
# print(df['Payment Method'].unique())
# print(df['Location'].unique())
# print(df['Transaction Date'].unique())

for col in df.columns:
    print(f"{col}: {df[col].unique()}")
# Out:
# Transaction ID: ['TXN_1961373' 'TXN_4977031' 'TXN_4271903' ... 'TXN_7672686' 'TXN_5255387'
#  'TXN_6170729']
# Item: ['Coffee' 'Cake' 'Cookie' 'Salad' 'Smoothie' 'Sandwich' 'Juice' 'Tea']
# Quantity: [2 4 5 3 1]
# Price Per Unit: [2.0 3.0 1.0 5.0 4.0 1.5]
# Total Spent: ['4.0' '12.0' 4.0 '10.0' '20.0' '9.0' '16.0' '15.0' '25.0' '8.0' '5.0'
#  '3.0' '6.0' 12.0 2.0 3.0 '2.0' '1.0' '7.5' 9.0 '1.5' 6.0 '4.5' 20.0 7.5
#  15.0 10.0 25.0 8.0 1.0 16.0 1.5 4.5 5.0]
# Payment Method: ['Credit Card' 'Cash' 'UNKNOWN' 'Digital Wallet' 'ERROR' '']
# Location: ['Takeaway' 'In-store' 'UNKNOWN']
# Transaction Date: ['2023-09-08' '2023-05-16' '2023-07-19' '2023-04-27' '2023-06-11'
#  '2023-03-31' '2023-10-06' '2023-10-28' '2023-07-28' '2023-12-31'
#  '2023-11-07' '2023-05-03' '2023-06-01' '2023-03-21' '2023-11-15'
#  '2023-06-10' '2023-02-24' '2023-03-25' '2023-01-15' '2023-03-30'
#  '2023-12-01' '2023-09-18' '2023-06-03' '2023-12-13' '2023-04-20'
#  '2023-04-10' '2023-03-11' '2023-06-02' '2023-11-06' '2023-08-15'
#  '2023-10-09' '2023-05-28' '2023-07-17' '2023-04-29' '2023-06-08'
#  '2023-06-29' '2023-04-17' '2023-12-22' '2023-01-10' '2023-10-02'
#  '2023-02-23' '2023-03-22' '2023-11-03' '2023-03-02' '2023-06-26'
#  '2023-05-02' '2023-09-05' '2023-01-08' '2023-03-15' '2023-11-25'
#  '2023-12-05' '2023-10-07' '2023-09-30' '2023-05-27' '2023-11-18'
#  '2023-10-03' '2023-04-06' '2023-01-31' '2023-12-08' '2023-06-19'
#  '2023-12-14' '2023-07-16' '2023-02-22' '2023-06-15' '2023-12-09'
#  '2023-04-18' '2023-04-30' '2023-04-02' '2023-05-24' '2023-03-12'
#  '2023-08-16' '2023-09-10' '2023-03-07' '2023-08-07' '2023-08-20'
#  '2023-04-15' '2023-07-25' '2023-10-30' '2023-12-15' '2023-02-25'
#  '2023-04-03' '2023-10-08' '2023-12-28' '2023-08-30' '2023-02-03'
#  '2023-09-12' '2023-05-04' '2023-02-21' '2023-03-16' '2023-03-29'
#  '2023-06-18' '2023-09-23' '2023-01-14' '2023-09-14' '2023-09-16'
#  '2023-02-06' '2023-04-08' '2023-12-19' '2023-07-14' '2023-12-12'
#  '2023-01-05' '2023-01-23' '2023-02-20' '2023-12-06' '2023-05-31'
#  '2023-08-11' '2023-09-03' '2023-07-11' '2023-01-18' '2023-03-23'
#  '2023-06-23' '2023-08-03' '2023-07-12' '2023-06-27' '2023-09-19'
#  '2023-09-04' '2023-05-21' '2023-07-02' '2023-07-10' '2023-11-21'
#  '2023-12-02' '2023-03-13' '2023-08-12' '2023-02-16' '2023-03-26'
#  '2023-11-01' '2023-07-22' '2023-02-28' '2023-01-27' '2023-01-19'
#  '2023-04-07' '2023-03-20' '2023-12-27' '2023-02-18' '2023-05-15'
#  '2023-12-10' '2023-04-21' '2023-02-04' '2023-11-12' '2023-08-05'
#  '2023-05-10' '2023-07-15' '2023-04-26' '2023-08-25' '2023-03-01'
#  '2023-11-13' '2023-07-09' '2023-05-13' '2023-05-18' '2023-04-04'
#  '2023-09-22' '2023-08-22' '2023-07-27' '2023-12-30' '2023-12-21'
#  '2023-09-28' '2023-04-14' '2023-01-03' '2023-10-20' '2023-01-12'
#  '2023-08-31' '2023-07-07' '2023-09-15' '2023-10-21' '2023-09-02'
#  '2023-08-19' '2023-01-06' '2023-10-13' '2023-05-29' '2023-11-16'
#  '2023-05-22' '2023-11-23' '2023-10-15' '2023-11-14' '2023-12-17'
#  '2023-05-09' '2023-10-22' '2023-06-30' '2023-12-11' '2023-04-25'
#  '2023-10-12' '2023-11-02' '2023-07-04' '2023-01-28' '2023-02-26'
#  '2023-10-11' '2023-02-14' '2023-09-06' '2023-04-23' '2023-01-22'
#  '2023-03-10' '2023-01-09' '2023-12-03' '2023-10-26' '2023-08-06'
#  '2023-01-11' '2023-12-29' '2023-05-25' '2023-10-31' '2023-02-27'
#  '2023-03-03' '2023-09-27' '2023-08-18' '2023-12-16' '2023-06-07'
#  '2023-05-12' '2023-07-06' '2023-06-20' '2023-08-09' '2023-05-14'
#  '2023-11-26' '2023-10-10' '2023-02-02' '2023-08-14' '2023-09-26'
#  '2023-01-13' '2023-10-16' '2023-11-17' '2023-12-20' '2023-02-08'
#  '2023-09-11' '2023-02-01' '2023-03-14' '2023-09-29' '2023-04-22'
#  '2023-07-31' '2023-06-06' '2023-06-13' '2023-03-06' '2023-01-30'
#  '2023-04-09' '2023-04-16' '2023-12-23' '2023-03-05' '2023-03-24'
#  '2023-07-23' '2023-07-29' '2023-06-05' '2023-10-19' '2023-01-07'
#  '2023-11-29' '2023-10-27' '2023-07-05' '2023-12-24' '2023-05-07'
#  '2023-08-10' '2023-10-24' '2023-08-13' '2023-08-28' '2023-06-21'
#  '2023-03-28' '2023-11-10' '2023-10-18' '2023-05-19' '2023-06-24'
#  '2023-05-11' '2023-12-07' '2023-09-01' '2023-01-04' '2023-09-25'
#  '2023-05-30' '2023-04-24' '2023-09-20' '2023-02-09' '2023-02-07'
#  '2023-05-05' '2023-02-10' '2023-10-25' '2023-10-05' '2023-07-21'
#  '2023-02-19' '2023-07-08' '2023-06-28' '2023-09-09' '2023-10-01'
#  '2023-08-21' '2023-03-19' '2023-07-01' '2023-06-14' '2023-03-09'
#  '2023-11-08' '2023-12-26' '2023-09-13' '2023-05-23' '2023-08-24'
#  '2023-04-01' '2023-06-09' '2023-08-23' '2023-08-08' '2023-08-27'
#  '2023-06-16' '2023-12-25' '2023-01-25' '2023-10-23' '2023-05-06'
#  '2023-01-29' '2023-08-29' '2023-07-24' '2023-04-12' '2023-01-17'
#  '2023-12-18' '2023-09-21' '2023-05-01' '2023-02-05' '2023-02-11'
#  '2023-01-24' '2023-01-02' '2023-06-12' '2023-10-17' '2023-03-04'
#  '2023-06-17' '2023-02-15' '2023-04-11' '2023-03-18' '2023-10-29'
#  '2023-08-26' '2023-06-22' '2023-05-17' '2023-11-22' '2023-08-17'
#  '2023-11-19' '2023-11-27' '2023-06-04' '2023-09-17' '2023-11-04'
#  '2023-11-28' '2023-04-19' '2023-11-09' '2023-06-25' '2023-01-16'
#  '2023-07-18' '2023-04-28' '2023-03-17' '2023-04-13' '2023-01-26'
#  '2023-08-04' '2023-05-26' '2023-05-08' '2023-07-26' '2023-11-24'
#  '2023-11-20' '2023-12-04' '2023-07-20' '2023-09-24' '2023-01-21'
#  '2023-07-13' '2023-03-08' '2023-09-07' '2023-11-30' '2023-08-02'
#  '2023-04-05' '2023-08-01' '2023-01-20' '2023-11-11' '2023-02-13'
#  '2023-07-30' '2023-02-17' '2023-10-14' '2023-10-04' '2023-05-20'
#  '2023-11-05' '2023-01-01' '2023-03-27' '2023-07-03' '2023-02-12']

# %%
print(df['Item'].value_counts())
# Out:
# Item
# Coffee      1835
# Juice       1020
# Cake         989
# Salad        985
# Sandwich     969
# Smoothie     951
# Cookie       929
# Tea          918
# Name: count, dtype: int64

# %%
print(df['Payment Method'].value_counts())
# Out:
# Payment Method
#                   2188
# Digital Wallet    1980
# Cash              1957
# Credit Card       1955
# ERROR              261
# UNKNOWN            255
# Name: count, dtype: int64

# %%
df['Payment Method'] = df['Payment Method'].replace(['', 'ERROR', 'UNKNOWN'], 'UNKNOWN')

# %%
print(df['Payment Method'].value_counts(normalize=True)*100)
# Out:
# Payment Method
# UNKNOWN           31.456491
# Digital Wallet    23.033969
# Cash              22.766403
# Credit Card       22.743136
# Name: proportion, dtype: float64

# %%
print(df['Transaction ID'].unique())
print(df['Item'].unique())
print(df['Quantity'].unique())
print(df['Price Per Unit'].unique())
print(df['Total Spent'].unique())
print(df['Payment Method'].unique())
print(df['Location'].unique())
# Out:
# ['TXN_1961373' 'TXN_4977031' 'TXN_4271903' ... 'TXN_7672686' 'TXN_5255387'
#  'TXN_6170729']
# ['Coffee' 'Cake' 'Cookie' 'Salad' 'Smoothie' 'Sandwich' 'Juice' 'Tea']
# [2 4 5 3 1]
# [2.0 3.0 1.0 5.0 4.0 1.5]
# ['4.0' '12.0' 4.0 '10.0' '20.0' '9.0' '16.0' '15.0' '25.0' '8.0' '5.0'
#  '3.0' '6.0' 12.0 2.0 3.0 '2.0' '1.0' '7.5' 9.0 '1.5' 6.0 '4.5' 20.0 7.5
#  15.0 10.0 25.0 8.0 1.0 16.0 1.5 4.5 5.0]
# ['Credit Card' 'Cash' 'UNKNOWN' 'Digital Wallet']
# ['Takeaway' 'In-store' 'UNKNOWN']

# %%
mask_4 = (df['Payment Method'].str.lower() == 'unknown') & (df['Item'].str.lower() == 'unknwon Item') & (df['Location'].str.lower() == 'unknown')
df = df[~mask_4]

# %% [markdown]
# ### create one clean CSV file

# %%
df.to_csv('Clean Cafe sales_final.csv', index=False)
